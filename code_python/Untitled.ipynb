# %%
import pymc3 as pm
import arviz as az
import numpy as np
import matplotlib as plt

# %%
N = 20
M = 8
idx = np.repeat(range(M-1), N)
idx = np.append(idx, 7)
np.random.seed(314)
alpha_real = np.random.normal(2.5, 0.5, size=M)
beta_real = np.random.beta(6, 1, size=M)
eps_real = np.random.normal(0, 0.5, size=len(idx))
y_m = np.zeros(len(idx))
x_m = np.random.normal(10, 1, len(idx))
y_m = alpha_real[idx] + beta_real[idx] * x_m + eps_real

# %%
eps_real
# Out:
# array([-0.11566774, -0.5736125 , -0.21147267,  0.66527348, -0.46391691,
#         0.05263992, -0.54877832, -0.43519044, -0.44145181,  0.1996012 ,
#         0.02734461, -0.42478074,  0.49314235,  0.14796762,  0.85492373,
#        -0.18875911, -0.13696786, -0.56962869, -0.20213269, -0.44977507,
#        -0.22793724,  0.10929657,  0.32948942, -0.57553264, -0.08519489,
#        -0.5062244 ,  0.08881419, -0.6240479 ,  0.18173299,  0.74163852,
#        -0.14072918,  0.20772063, -0.27414699,  0.12183882, -0.18622776,
#         0.43110797, -0.70177258,  0.70684457, -0.22034167,  0.60055468,
#        -0.73653815, -0.07901398, -0.33504728, -0.51332503,  0.64305055,
#         0.07818517, -0.41581567,  0.94686655,  0.89553949,  0.04526774,
#         0.02842187, -0.0739509 , -0.42582986, -0.30249113,  0.43229403,
#        -1.11013215,  0.16450045, -0.64630497,  0.42566713, -0.66785263,
#         0.10511959, -0.29787465,  0.11782763,  0.36737215,  0.50830927,
#         0.0447575 , -0.53296842,  0.21020297,  0.09318996, -0.76687248,
#        -0.04238836,  0.00643404,  0.3299787 ,  0.31937224,  0.06090066,
#         1.08658127,  0.01525013,  0.28655408, -0.56570004, -0.53136938,
#         0.96366715, -0.4282719 , -0.11529923,  0.87102974,  0.62883725,
#         0.47531374, -0.25644232,  0.00194759,  0.00383922, -0.26254556,
#         0.92157604, -0.2295135 ,  0.3328088 ,  1.09375369,  0.24293561,
#         0.31962638,  0.24675977, -0.29758114,  0.43056305, -0.17130776,
#         0.27952987,  0.22034825,  0.44564885,  0.80539536, -0.57297969,
#         0.02018063,  0.04873816, -0.03228929, -0.09492037, -0.16173499,
#        -0.16152242, -0.35856067, -0.20651449, -1.10152008,  0.48904279,
#         0.34788001,  0.21079751, -0.10979031,  1.19697601, -1.02962741,
#        -0.06057207, -0.58479673, -0.13596929, -0.77426433, -0.50122073,
#         0.14775862, -0.34422145, -0.14642904,  0.07858849, -0.07242827,
#         0.76374081, -0.12266632,  1.11640458,  0.33105659,  0.01844098,
#        -0.45646047, -0.49467309,  0.16044045,  0.57658012,  0.0312232 ,
#        -0.300997  ])
